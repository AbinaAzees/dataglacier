# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
Cabdata=pd.read_csv('Cab_Data.csv')

# %%
Cabdata
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 0             10000011           42377    Pink Cab     ATLANTA GA
# 1             10000012           42375    Pink Cab     ATLANTA GA
# 2             10000013           42371    Pink Cab     ATLANTA GA
# 3             10000014           42376    Pink Cab     ATLANTA GA
# 4             10000015           42372    Pink Cab     ATLANTA GA
# ...                ...             ...         ...            ...
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
# 359391        10440107           43102  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip
# 0              30.45         370.95      313.6350
# 1              28.62         358.52      334.8540
# 2               9.04         125.20       97.6320
# 3              33.17         377.40      351.6020
# 4               8.73         114.62       97.7760
# ...              ...            ...           ...
# 359387          4.80          69.24       63.3600
# 359388          8.40         113.75      106.8480
# 359389         27.75         437.07      349.6500
# 359390          8.80         146.19      114.0480
# 359391         12.76         191.58      177.6192
#
# [359392 rows x 7 columns]

# %%
Cabdata.isnull().sum()
# Out:
# Transaction ID    0
# Date of Travel    0
# Company           0
# City              0
# KM Travelled      0
# Price Charged     0
# Cost of Trip      0
# Tip               0
# dtype: int64

# %%
Cabdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  int64
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 19.2+ MB

# %%
dateTravel = Cabdata['Date of Travel'].to_list()
ourBaseDate = pd.Timestamp('1899-12-29')
dates = [ourBaseDate + pd.DateOffset(date_offset) for date_offset in dateTravel]
Cabdata['Date of Travel'] = pd.to_datetime(dates, format='%y/%m/%d')

# %%
copy=Cabdata.drop_duplicates(subset=["Transaction ID"])
top21=copy.groupby("Company").count()["Transaction ID"]
copy.groupby("Company").count()
# Out:
#             Transaction ID  Date of Travel    City  KM Travelled  \
# Company
# Pink Cab             84711           84711   84711         84711
# Yellow Cab          274681          274681  274681        274681
#
#             Price Charged  Cost of Trip
# Company
# Pink Cab            84711         84711
# Yellow Cab         274681        274681

# %%
City=pd.read_csv('City.csv')

# %%
City
# Out:
#                 City   Population      Users
# 0        NEW YORK NY   8,405,837    302,149
# 1         CHICAGO IL   1,955,130    164,468
# 2     LOS ANGELES CA   1,595,037    144,132
# 3           MIAMI FL   1,339,155     17,675
# 4     SILICON VALLEY   1,177,609     27,247
# 5      ORANGE COUNTY   1,030,185     12,994
# 6       SAN DIEGO CA     959,307     69,995
# 7         PHOENIX AZ     943,999      6,133
# 8          DALLAS TX     942,908     22,157
# 9         ATLANTA GA     814,885     24,701
# 10         DENVER CO     754,233     12,421
# 11         AUSTIN TX     698,371     14,978
# 12        SEATTLE WA     671,238     25,063
# 13         TUCSON AZ     631,442      5,712
# 14  SAN FRANCISCO CA     629,591    213,609
# 15     SACRAMENTO CA     545,776      7,044
# 16     PITTSBURGH PA     542,085      3,643
# 17     WASHINGTON DC     418,859    127,001
# 18      NASHVILLE TN     327,225      9,270
# 19         BOSTON MA     248,968     80,021

# %%
City["Population"]=[a.replace(",","") for a in City.Population]
City["Users"]=[a.replace(",","") for a in City.Users]
City = City.astype({'Population':'int','Users':'int'})
City.info()
City
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        20 non-null     object
#  1   Population  20 non-null     int32
#  2   Users       20 non-null     int32
# dtypes: int32(2), object(1)
# memory usage: 452.0+ bytes
#                 City  Population   Users
# 0        NEW YORK NY     8405837  302149
# 1         CHICAGO IL     1955130  164468
# 2     LOS ANGELES CA     1595037  144132
# 3           MIAMI FL     1339155   17675
# 4     SILICON VALLEY     1177609   27247
# 5      ORANGE COUNTY     1030185   12994
# 6       SAN DIEGO CA      959307   69995
# 7         PHOENIX AZ      943999    6133
# 8          DALLAS TX      942908   22157
# 9         ATLANTA GA      814885   24701
# 10         DENVER CO      754233   12421
# 11         AUSTIN TX      698371   14978
# 12        SEATTLE WA      671238   25063
# 13         TUCSON AZ      631442    5712
# 14  SAN FRANCISCO CA      629591  213609
# 15     SACRAMENTO CA      545776    7044
# 16     PITTSBURGH PA      542085    3643
# 17     WASHINGTON DC      418859  127001
# 18      NASHVILLE TN      327225    9270
# 19         BOSTON MA      248968   80021

# %%
City.isnull().sum()
# Out:
# City          0
# Population    0
# Users         0
# dtype: int64

# %%
CustomID=pd.read_csv('Customer_ID.csv')

# %%
CustomID.info()
CustomID
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         49171 non-null  int64
#  1   Gender              49171 non-null  object
#  2   Age                 49171 non-null  int64
#  3   Income (USD/Month)  49171 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
#        Customer ID  Gender  Age  Income (USD/Month)
# 0            29290    Male   28               10813
# 1            27703    Male   27                9237
# 2            28712    Male   53               11242
# 3            28020    Male   23               23327
# 4            27182    Male   33                8536
# ...            ...     ...  ...                 ...
# 49166        12490    Male   33               18713
# 49167        14971    Male   30               15346
# 49168        41414    Male   38                3960
# 49169        41677    Male   23               19454
# 49170        39761  Female   32               10128
#
# [49171 rows x 4 columns]

# %%
TranstID=pd.read_csv('Transaction_ID.csv')
TranstID.info()
TranstID
TranstID.info()
TranstID
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440098 entries, 0 to 440097
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  440098 non-null  int64
#  1   Customer ID     440098 non-null  int64
#  2   Payment_Mode    440098 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 10.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440098 entries, 0 to 440097
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  440098 non-null  int64
#  1   Customer ID     440098 non-null  int64
#  2   Payment_Mode    440098 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 10.1+ MB
#         Transaction ID  Customer ID Payment_Mode
# 0             10000011        29290         Card
# 1             10000012        27703         Card
# 2             10000013        28712         Cash
# 3             10000014        28020         Cash
# 4             10000015        27182         Card
# ...                ...          ...          ...
# 440093        10440104        53286         Cash
# 440094        10440105        52265         Cash
# 440095        10440106        52175         Card
# 440096        10440107        52917         Card
# 440097        10440108        51587         Card
#
# [440098 rows x 3 columns]

# %%
TranstID.isnull().sum()
# Out:
# Transaction ID    0
# Customer ID       0
# Payment_Mode      0
# dtype: int64

# %%
Cabdata["Tip"]=Cabdata["Price Charged"]-Cabdata["Cost of Trip"]
Cabdata
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011     2016-01-07    Pink Cab     ATLANTA GA
# 1             10000012     2016-01-05    Pink Cab     ATLANTA GA
# 2             10000013     2016-01-01    Pink Cab     ATLANTA GA
# 3             10000014     2016-01-06    Pink Cab     ATLANTA GA
# 4             10000015     2016-01-02    Pink Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10440101     2018-01-07  Yellow Cab  WASHINGTON DC
# 359388        10440104     2018-01-03  Yellow Cab  WASHINGTON DC
# 359389        10440105     2018-01-04  Yellow Cab  WASHINGTON DC
# 359390        10440106     2018-01-04  Yellow Cab  WASHINGTON DC
# 359391        10440107     2018-01-01  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip      Tip
# 0              30.45         370.95      313.6350  57.3150
# 1              28.62         358.52      334.8540  23.6660
# 2               9.04         125.20       97.6320  27.5680
# 3              33.17         377.40      351.6020  25.7980
# 4               8.73         114.62       97.7760  16.8440
# ...              ...            ...           ...      ...
# 359387          4.80          69.24       63.3600   5.8800
# 359388          8.40         113.75      106.8480   6.9020
# 359389         27.75         437.07      349.6500  87.4200
# 359390          8.80         146.19      114.0480  32.1420
# 359391         12.76         191.58      177.6192  13.9608
#
# [359392 rows x 8 columns]

# %%
plot=Cabdata[["Date of Travel","Company","Price Charged"]]
plot=plot.groupby(["Date of Travel"]).sum("Price Charged")
plot=plot.groupby([pd.Grouper(freq='ME')]).sum()["Price Charged"]
plott=plot.reset_index()
plott
# Out:
#    Date of Travel  Price Charged
# 0      2016-01-31     2303744.78
# 1      2016-02-29     2744742.31
# 2      2016-03-31     2883035.41
# 3      2016-04-30     3089676.80
# 4      2016-05-31     3329398.45
# 5      2016-06-30     3473596.34
# 6      2016-07-31     3691470.51
# 7      2016-08-31     3646549.90
# 8      2016-09-30     4795413.29
# 9      2016-10-31     5082300.75
# 10     2016-11-30     5381161.39
# 11     2016-12-31     6398808.93
# 12     2017-01-31     3411429.05
# 13     2017-02-28     3087747.12
# 14     2017-03-31     3614846.33
# 15     2017-04-30     3554610.34
# 16     2017-05-31     3936279.22
# 17     2017-06-30     3810929.40
# 18     2017-07-31     3947250.65
# 19     2017-08-31     4641808.24
# 20     2017-09-30     5760365.35
# 21     2017-10-31     5809824.79
# 22     2017-11-30     6519604.12
# 23     2017-12-31     7018955.72
# 24     2018-01-31     4303576.04
# 25     2018-02-28     2680412.16
# 26     2018-03-31     3250023.86
# 27     2018-04-30     3010253.70
# 28     2018-05-31     3690774.58
# 29     2018-06-30     3480724.85
# 30     2018-07-31     3454278.04
# 31     2018-08-31     4313508.21
# 32     2018-09-30     4695932.13
# 33     2018-10-31     5252734.30
# 34     2018-11-30     6170997.16
# 35     2018-12-31     5945374.30

# %%
copy=Cabdata.drop_duplicates(subset=["Transaction ID"])
top21=copy.groupby("Company").count()["Transaction ID"]
copy.groupby("Company").count()
# Out:
#             Transaction ID  Date of Travel    City  KM Travelled  \
# Company
# Pink Cab             84711           84711   84711         84711
# Yellow Cab          274681          274681  274681        274681
#
#             Price Charged  Cost of Trip     Tip
# Company
# Pink Cab            84711         84711   84711
# Yellow Cab         274681        274681  274681

# %%
top21
# Out:
# Company
# Pink Cab       84711
# Yellow Cab    274681
# Name: Transaction ID, dtype: int64

# %%
plt.figure(figsize=(10,8))
plt.title("Total Transactions")
sbn.countplot(data=copy,x="Company")
plt.show()

# %%
plt.figure(figsize=(30,13))
plt.title("Total Customer by city",fontsize=20)
sbn.countplot(data=copy,hue="Company",x="City")
plt.show()

# %%
MergData= Cabdata.merge(TranstID, on= 'Transaction ID').merge(CustomID, on ='Customer ID').merge(City, on = 'City')
MergData
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011     2016-01-07    Pink Cab     ATLANTA GA
# 1             10000012     2016-01-05    Pink Cab     ATLANTA GA
# 2             10000013     2016-01-01    Pink Cab     ATLANTA GA
# 3             10000014     2016-01-06    Pink Cab     ATLANTA GA
# 4             10000015     2016-01-02    Pink Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10440101     2018-01-07  Yellow Cab  WASHINGTON DC
# 359388        10440104     2018-01-03  Yellow Cab  WASHINGTON DC
# 359389        10440105     2018-01-04  Yellow Cab  WASHINGTON DC
# 359390        10440106     2018-01-04  Yellow Cab  WASHINGTON DC
# 359391        10440107     2018-01-01  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip      Tip  Customer ID  \
# 0              30.45         370.95      313.6350  57.3150        29290
# 1              28.62         358.52      334.8540  23.6660        27703
# 2               9.04         125.20       97.6320  27.5680        28712
# 3              33.17         377.40      351.6020  25.7980        28020
# 4               8.73         114.62       97.7760  16.8440        27182
# ...              ...            ...           ...      ...          ...
# 359387          4.80          69.24       63.3600   5.8800        52392
# 359388          8.40         113.75      106.8480   6.9020        53286
# 359389         27.75         437.07      349.6500  87.4200        52265
# 359390          8.80         146.19      114.0480  32.1420        52175
# 359391         12.76         191.58      177.6192  13.9608        52917
#
#        Payment_Mode Gender  Age  Income (USD/Month)  Population   Users
# 0              Card   Male   28               10813      814885   24701
# 1              Card   Male   27                9237      814885   24701
# 2              Cash   Male   53               11242      814885   24701
# 3              Cash   Male   23               23327      814885   24701
# 4              Card   Male   33                8536      814885   24701
# ...             ...    ...  ...                 ...         ...     ...
# 359387         Cash   Male   24               15651      418859  127001
# 359388         Cash   Male   32                6528      418859  127001
# 359389         Cash   Male   56                7966      418859  127001
# 359390         Card   Male   32                6423      418859  127001
# 359391         Card   Male   20               11284      418859  127001
#
# [359392 rows x 15 columns]

# %%
MergData
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011     2016-01-07    Pink Cab     ATLANTA GA
# 1             10000012     2016-01-05    Pink Cab     ATLANTA GA
# 2             10000013     2016-01-01    Pink Cab     ATLANTA GA
# 3             10000014     2016-01-06    Pink Cab     ATLANTA GA
# 4             10000015     2016-01-02    Pink Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10440101     2018-01-07  Yellow Cab  WASHINGTON DC
# 359388        10440104     2018-01-03  Yellow Cab  WASHINGTON DC
# 359389        10440105     2018-01-04  Yellow Cab  WASHINGTON DC
# 359390        10440106     2018-01-04  Yellow Cab  WASHINGTON DC
# 359391        10440107     2018-01-01  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip      Tip  Customer ID  \
# 0              30.45         370.95      313.6350  57.3150        29290
# 1              28.62         358.52      334.8540  23.6660        27703
# 2               9.04         125.20       97.6320  27.5680        28712
# 3              33.17         377.40      351.6020  25.7980        28020
# 4               8.73         114.62       97.7760  16.8440        27182
# ...              ...            ...           ...      ...          ...
# 359387          4.80          69.24       63.3600   5.8800        52392
# 359388          8.40         113.75      106.8480   6.9020        53286
# 359389         27.75         437.07      349.6500  87.4200        52265
# 359390          8.80         146.19      114.0480  32.1420        52175
# 359391         12.76         191.58      177.6192  13.9608        52917
#
#        Payment_Mode Gender  Age  Income (USD/Month)  Population   Users
# 0              Card   Male   28               10813      814885   24701
# 1              Card   Male   27                9237      814885   24701
# 2              Cash   Male   53               11242      814885   24701
# 3              Cash   Male   23               23327      814885   24701
# 4              Card   Male   33                8536      814885   24701
# ...             ...    ...  ...                 ...         ...     ...
# 359387         Cash   Male   24               15651      418859  127001
# 359388         Cash   Male   32                6528      418859  127001
# 359389         Cash   Male   56                7966      418859  127001
# 359390         Card   Male   32                6423      418859  127001
# 359391         Card   Male   20               11284      418859  127001
#
# [359392 rows x 15 columns]

# %%
TotalAge=MergData.groupby("Age")[["Price Charged"]].mean()
totalage=TotalAge.reset_index()

# %%
#Average taxi fare by age.
plt.figure(figsize=(20,10))
plt.title("Average taxi fare by age",fontsize=15)
sbn.barplot(data=totalage,x="Age",y="Price Charged")
# Out:
# <Axes: title={'center': 'Average taxi fare by age'}, xlabel='Age', ylabel='Price Charged'>

# %%
plt.show()

# %%
TotaltipAge=MergData.groupby("Age")[["Tip"]].mean()
totaltipage=TotaltipAge.reset_index()
#Average tip fee by age.

plt.figure(figsize=(20,10))
plt.title("Average tip fee by age",fontsize=15)
sbn.barplot(data=totaltipage,x="Age",y="Tip")
# Out:
# <Axes: title={'center': 'Average tip fee by age'}, xlabel='Age', ylabel='Tip'>

# %%
plt.show()

# %%
MergDataaa=MergData.groupby(["Company","Payment_Mode"])[["Price Charged"]].sum()
MergDataaa=MergDataaa.reset_index()
#money earned by payment method.
plt.title("Money earned by payment method")
sbn.set_theme(style="whitegrid")
sbn.barplot(data=MergDataaa,hue="Company",x="Payment_Mode",y="Price Charged",palette="Blues_d")
# Out:
# <Axes: title={'center': 'Money earned by payment method'}, xlabel='Payment_Mode', ylabel='Price Charged'>

# %%
plt.show()

# %%
MergDataaa
# Out:
#       Company Payment_Mode  Price Charged
# 0    Pink Cab         Card    15783616.83
# 1    Pink Cab         Cash    10544634.50
# 2  Yellow Cab         Card    75459167.70
# 3  Yellow Cab         Cash    50394719.49

# %%
payment2=MergData.groupby(["Company","Payment_Mode"])["Transaction ID"].count()
payment2=payment2.reset_index()
payment2
# Out:
#       Company Payment_Mode  Transaction ID
# 0    Pink Cab         Card           50719
# 1    Pink Cab         Cash           33992
# 2  Yellow Cab         Card          164785
# 3  Yellow Cab         Cash          109896

# %%
sbn.set_theme(style="whitegrid")
sbn.barplot(data=payment2,x="Payment_Mode",hue="Company",y=payment2["Transaction ID"],palette="Blues_d")
# Out:
# <Axes: xlabel='Payment_Mode', ylabel='Transaction ID'>

# %%
plt.show()

# %%
MergeddData=MergData.drop_duplicates(subset=["Transaction ID"])
MergeddData=MergeddData.groupby("Age").count()["Transaction ID"]
MergeddData=MergeddData.reset_index()
plt.figure(figsize=(20,20))
plt.title("Number of users by age",loc="left",fontstyle='italic',fontsize=20)
plt.pie(MergeddData["Transaction ID"],shadow=True,autopct='%1.1f%%',data=MergeddData,labels="Age",startangle=90)
plt.axis('equal')
# Out:
# (-1.0999999998453398,
#  1.099999999992513,
#  -1.0999999999724457,
#  1.0999999999986878)

# %%
plt.show()

# %%
MergeddData=MergData.drop_duplicates(subset=["Transaction ID"])
MergeddData=MergeddData.groupby("Gender").count()["Transaction ID"]
MergeddData=MergeddData.reset_index()
plt.figure(figsize=(20,20))
plt.title("Number of users by gender",loc="left",fontstyle='italic',fontsize=20)
plt.pie(MergeddData["Transaction ID"],shadow=True,autopct='%1.1f%%',data=MergeddData,labels="Gender",startangle=90)
plt.axis('equal')
# Out:
# (-1.0999913511372872,
#  1.0999985207998928,
#  -1.0999999995923775,
#  1.0999999999805894)

# %%
plt.show()
